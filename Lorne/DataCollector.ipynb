# %%
import databento as db
client = db.Historical("db-niBd3fUGuCYpx9YuUygCNB3upxA68")
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
data = client.timeseries.get_range(
    dataset="GLBX.MDP3",
    symbols="ESH4", 
    schema="trades",  # You'll use this to resample later
    start="2024-02-12",
    end="2024-02-17",
)
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd

trades_df = data.to_df() # Convert to a Pandas DataFrame

# Resample to 5-minute bars
resampled_df = (
    trades_df.groupby([trades_df.index.to_period("5min"), "symbol"])
    .agg({"price": "ohlc", "size": "sum"})
    .reset_index("symbol")
)
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-3-f0372e354d5f>:7: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   trades_df.groupby([trades_df.index.to_period("5min"), "symbol"])

# %%
print(resampled_df)
# Out:
#                  symbol    price                            size
#                             open     high      low    close size
# ts_recv
# 2024-02-12 00:00   ESH4  5042.25  5042.50  5042.25  5042.50   37
# 2024-02-12 00:01   ESH4  5042.50  5042.75  5042.50  5042.75   64
# 2024-02-12 00:02   ESH4  5042.50  5043.00  5042.50  5043.00   21
# 2024-02-12 00:03   ESH4  5043.00  5043.25  5043.00  5043.25   22
# 2024-02-12 00:04   ESH4  5043.50  5043.50  5043.25  5043.25   90
# ...                 ...      ...      ...      ...      ...  ...
# 2024-02-16 21:55   ESH4  5015.00  5015.00  5014.75  5015.00  182
# 2024-02-16 21:56   ESH4  5015.00  5015.00  5014.75  5015.00  385
# 2024-02-16 21:57   ESH4  5015.00  5015.00  5014.75  5015.00  294
# 2024-02-16 21:58   ESH4  5015.00  5015.00  5014.50  5014.50  480
# 2024-02-16 21:59   ESH4  5014.50  5015.00  5014.50  5014.50  613
#
# [6821 rows x 6 columns]
# ...

# %%
curl --request GET \
     --url 'https://data.alpaca.markets/v1beta1/options/bars?symbols=AAL&timeframe=5%20min&start=2024-01-03T00%3A00%3A00Z&end=2024-01-04T00%3A00%3A00Z&limit=1000&page_token=d&sort=asc' \
     --header 'accept: application/json'
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   File "<ipython-input-5-29a39fc0cccc>", line 1
#     curl --request GET \
#                    ^
# SyntaxError: invalid syntax

# %%
import requests

# Define the URL you want to request
url = 'https://data.alpaca.markets/v1beta1/options/bars?symbols=AAL&timeframe=5%20min&start=2024-01-03T00%3A00%3A00Z&end=2024-01-04T00%3A00%3A00Z&limit=1000&page_token=d&sort=asc'  # This URL echoes back the received headers

# Define your custom headers as a dictionary
headers = {
   'accept: application/json'
}

# Make the GET request with the specified headers
response = requests.get(url, headers=headers)

# Print the response content
print("Response Status Code:", response.status_code)
print("Response Headers:", response.headers)
print("Response Body:", response.text)
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c5333a439a80> in <module>
#      10
#      11 # Make the GET request with the specified headers
# ---> 12 response = requests.get(url, headers=headers)
#      13
#      14 # Print the response content
#
# ~/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ...

# %%
import requests

url = "https://data.alpaca.markets/v1beta1/options/bars?symbols=AAL&timeframe=15Min&start=2024-01-03T00%3A00%3A00Z&end=2024-01-04T00%3A00%3A00Z&limit=10&page_token=d&sort=asc"

headers = {
    "accept": "application/json",
    "APCA-API-KEY-ID": "CKRY24DCG9OUBP7H6AKJ",
    "APCA-API-SECRET-KEY": "zu0qIJfMj8mi6pFNZgKj2UzZoczYowPwLMq1cdrU"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <html>
# <head><title>403 Forbidden</title></head>
# <body>
# <center><h1>403 Forbidden</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>

# %%
from alpaca.data.historical import CryptoHistoricalDataClient

# No keys required for crypto data
client = CryptoHistoricalDataClient()
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame
from datetime import datetime

# Creating request object
request_params = CryptoBarsRequest(
  symbol_or_symbols=["BTC/USD"],
  #timeframe=TimeFrame.Hour(5),
  timeframe=TimeFrame(45, TimeFrameUnit.Minute),
  start=datetime(2022, 9, 1),
  end=datetime(2022, 9, 7)
)
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1e161c72db44> in <module>
#       7   symbol_or_symbols=["BTC/USD"],
#       8   #timeframe=TimeFrame.Hour(5),
# ----> 9   timeframe=TimeFrame(45, TimeFrameUnit.Minute),
#      10   start=datetime(2022, 9, 1),
#      11   end=datetime(2022, 9, 7)
#
# NameError: name 'TimeFrameUnit' is not defined

# %%
# Retrieve daily bars for Bitcoin in a DataFrame and printing it
btc_bars = client.get_crypto_bars(request_params)

# Convert to dataframe
btc_bars.df
# Out:
# /home/lb/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                        open      high       low     close  \
# symbol  timestamp
# BTC/USD 2022-09-01 00:00:00+00:00  20051.81  20139.53  19915.87  20060.81
#         2022-09-01 01:00:00+00:00  20061.09  20183.83  20052.47  20123.27
#         2022-09-01 02:00:00+00:00  20128.64  20205.83  20070.18  20117.06
#         2022-09-01 03:00:00+00:00  20119.07  20179.31  19925.00  20030.01
#         2022-09-01 04:00:00+00:00  20026.42  20094.22  19977.91  20056.65
# ...                                     ...       ...       ...       ...
#         2022-09-06 20:00:00+00:00  18825.90  19025.99  18668.90  18987.58
# ...

# %%
from alpaca_trade_api.rest import REST, TimeFrame, TimeFrameUnit

api = REST('CKRY24DCG9OUBP7H6AKJ', 'zu0qIJfMj8mi6pFNZgKj2UzZoczYowPwLMq1cdrU')
api.get_bars("AAPL", TimeFrame(45, TimeFrameUnit.Minute), "2021-06-08", "2021-06-08", adjustment='raw').df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-59fc21e46f53> in <module>
#       2
#       3 api = REST('CKRY24DCG9OUBP7H6AKJ', 'zu0qIJfMj8mi6pFNZgKj2UzZoczYowPwLMq1cdrU')
# ----> 4 api.get_bars("AAPL", TimeFrame(45, TimeFrameUnit.Minute), "2021-06-08", "2021-06-08", adjustment='raw').df
#
# ~/anaconda3/lib/python3.8/site-packages/alpaca_trade_api/rest.py in get_bars(self, symbol, timeframe, start, end, adjustment, limit, feed, asof, sort)
#     733                  sort: Optional[Sort] = None,
#     734                  ) -> BarsV2:
# --> 735         bars = list(self.get_bars_iter(symbol,
#     736                                        timeframe,
#     737                                        start,
#
# ...

# %%
import sys

from alpaca_trade_api.rest import REST, TimeFrame, TimeFrameUnit

api = REST('PKJ41QP5QU0TYS4S1BYB', 'o5HVFGx0XWSMoMyeQdRJwG1apYXtuMNcguWpjqqe')

bar_iter = api.get_bars("AAPL", TimeFrame(15, TimeFrameUnit.Minute), "2021-06-08", "2024-06-09", adjustment='raw').df
#api = REST()
#api.get_trades("AAPL", "2021-06-08", "2021-06-08", limit=10).df


#print(bar_iter.close)

data = []

for i in bar_iter.close:
    data.append(float(i))

#for i in data:
#    print(sys.prefix)

import numpy as np
arr = np.array(data)
np.save('my_array.npy', arr)

# %%
import numpy as np

def read_npy_file(file_path):
    """
    Read a .npy file and return its contents as a NumPy array
    """
    try:
        data = np.load(file_path)
        print(f"Successfully loaded data from {file_path}")
        print(f"Data shape: {data.shape}")
        print(f"Data type: {data.dtype}")
        return data
    except FileNotFoundError:
        print(f"Error: File {file_path} not found")
    except Exception as e:
        print(f"Error loading file: {str(e)}")

# %%
# Example usage:
data = read_npy_file('my_array.npy')

for i in data:
    print(i)
# Out:
# Successfully loaded data from my_array.npy
# Data shape: (47429,)
# Data type: float64
# 126.06
# 126.17
# 126.3
# 126.3
# 126.32
# 126.23
# 126.28
# 126.38
# 126.28
# 125.9
# 126.3
# 126.49
# 126.75
# 126.66
# 126.83
# 126.83
# 126.74
# 126.87
# 126.83
# 126.93
# 126.9
# 126.62
# 128.2
# 127.025
# 127.415
# 127.495
# 127.425
# 127.135
# 127.17
# 126.455
# 126.7101
# 126.61
# 126.72
# 126.6788
# 126.655
# 126.825
# 126.595
# 126.4628
# 126.734
# 126.7072
# 126.8824
# 127.0279
# 127.06
# 127.285
# 127.255
# 127.005
# 126.935
# 126.74
# 126.78
# 126.75
# 126.68
# 126.66
# 126.67
# 126.74
# 126.72
# 126.66
# 126.7
# 126.71
# 126.7
# 126.73
# 126.71
# 126.76
# 126.72
# 126.64
# 127.25
# 126.96
# 126.99
# 126.97
# 126.88
# 126.91
# 127.04
# 126.96
# 127.0
# 126.83
# 126.95
# 127.1
# 127.13
# 127.19
# 127.11
# 127.09
# 126.99
# 126.88
# 127.17
# 127.16
# 127.2
# 127.18
# 127.105
# 126.9
# 126.745
# 127.099
# 127.1899
# 127.2
# 127.11
# 127.12
# 127.085
# 126.95
# 127.0599
# 127.125
# ...
